# %% [markdown]
# # Instructor Do: Create and Deploy a Machine Learning Model in Amazon SageMaker

# %%
# Initial imports
import os
import io
import json
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score


# Amazon SageMaker and related imports
import sagemaker
import sagemaker.amazon.common as smac
from sagemaker.predictor import csv_serializer, json_deserializer
from sagemaker import get_execution_role
from sagemaker.amazon.amazon_estimator import get_image_uri
import boto3  # AWS Python sdk

# %matplotlib inline

# %% [markdown]
# ## Reading Data

# %%
# Read the weather features data
file_path = Path("x_austin_final.csv")
features = pd.read_csv(file_path)

# Transforming the "TempAvgF" column to a vector
X = features["TempAvgF"].values.reshape(-1, 1)

# %%
# Read the target data (precipitation sum inches)
file_path = Path("y_austin_final.csv")
y = pd.read_csv(file_path, names=["PrecipitationSumInches"], header=None)

# Transforming y into a vector
y = y.iloc[:, 0].values

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ## Creating the Linear Regression Model
#
# ### Initial Configurations

# %%
# Define Amazon S3 Bucket to store model data
bucket = "10-43-sagemaker-11-7-2020"  #'<your_s3_bucket_name_here>'

# Define prefix for data files
prefix = "austin-rainfall-regression"

# AWS IAM role
role = get_execution_role()

# %% [markdown]
# ### Uploading Training Data to Amazon S3

# %%
# Encode the training data as Protocol Buffer
buf = io.BytesIO()
vectors = np.array(X_train).astype("float32")
labels = np.array(y_train).astype("float32")
smac.write_numpy_to_dense_tensor(buf, vectors, labels)
buf.seek(0)

# Upload encoded training data to Amazon S3
key = "linear_train.data"
boto3.resource("s3").Bucket(bucket).Object(
    os.path.join(prefix, "train", key)
).upload_fileobj(buf)
s3_train_data = "s3://{}/{}/train/{}".format(bucket, prefix, key)
print("Training data uploaded to: {}".format(s3_train_data))
# Out:
# Training data uploaded to: s3://10-43-sagemaker-11-7-2020/austin-rainfall-regression/train/linear_train.data

# %% [markdown]
# ### Upload Test Data to Amazon S3

# %%
# Encode the testing data as Protocol Buffer
buf = io.BytesIO()
vectors = np.array(X_test).astype("float32")
labels = np.array(y_test).astype("float32")
smac.write_numpy_to_dense_tensor(buf, vectors, labels)
buf.seek(0)

# Upload encoded testing data to Amazon S3
key = "linear_test.data"
boto3.resource("s3").Bucket(bucket).Object(
    os.path.join(prefix, "test", key)
).upload_fileobj(buf)
s3_test_data = "s3://{}/{}/test/{}".format(bucket, prefix, key)
print("Testing data uploaded to: {}".format(s3_test_data))
# Out:
# Testing data uploaded to: s3://10-43-sagemaker-11-7-2020/austin-rainfall-regression/test/linear_test.data

# %% [markdown]
# ### Creating Model Instance

# %%
# Create an instance of the linear learner algorithm
container = get_image_uri(boto3.Session().region_name, "linear-learner")
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.

# %%
# Start the Amazon SageMaker session
sess = sagemaker.Session()

# Create an instance of the linear learner estimator
linear = sagemaker.estimator.Estimator(
    container,
    role,
    train_instance_count=1,
    train_instance_type="ml.m4.xlarge",
    output_path="s3://{}/{}/output".format(bucket, prefix),
    sagemaker_session=sess,
)

# Define linear learner hyperparameters
linear.set_hyperparameters(
    feature_dim=1,
    mini_batch_size=100,
    predictor_type="regressor",
    epochs=10,
    num_models=32,
    loss="absolute_loss",
)
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# ## Training the Machine Learning Model

# %%
# Fitting the linear learner model with the training data
linear.fit({"train": s3_train_data, "test": s3_test_data})
# Out:
# 2020-11-07 19:47:11 Starting - Starting the training job...
# 2020-11-07 19:47:14 Starting - Launching requested ML instances......
# 2020-11-07 19:48:19 Starting - Preparing the instances for training......
# 2020-11-07 19:49:22 Downloading - Downloading input data...
# 2020-11-07 19:50:11 Training - Downloading the training image...
# 2020-11-07 19:50:41 Uploading - Uploading generated training modelDocker entrypoint called with argument(s): train
# Running default environment configuration script
# [11/07/2020 19:50:34 INFO 139935395739456] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [11/07/2020 19:50:34 INFO 139935395739456] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'loss': u'absolute_loss', u'mini_batch_size': u'100', u'predictor_type': u'regressor', u'epochs': u'10', u'feature_dim': u'1', u'num_models': u'32'}
# [11/07/2020 19:50:34 INFO 139935395739456] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'10', u'feature_dim': u'1', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'32', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'100', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'regressor', u'beta_1': u'auto', u'loss': u'absolute_loss', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [11/07/2020 19:50:34 WARNING 139935395739456] Loggers have already been setup.
# Process 1 is a worker.
# [11/07/2020 19:50:34 INFO 139935395739456] Using default worker.
# [11/07/2020 19:50:35 INFO 139935395739456] Checkpoint loading and saving are disabled.
# [2020-11-07 19:50:35.012] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2020-11-07 19:50:35.030] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 18, "num_examples": 1, "num_bytes": 4800}
# [11/07/2020 19:50:35 INFO 139935395739456] Create Store: local
# [2020-11-07 19:50:35.118] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 87, "num_examples": 11, "num_bytes": 50640}
# [11/07/2020 19:50:35 INFO 139935395739456] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f44e86ac0d0>
# [11/07/2020 19:50:35 INFO 139935395739456] Scaling model computed with parameters:
#  {'stdev_weight':
# [13.866885]
# <NDArray 1 @cpu(0)>, 'stdev_label':
# [0.45205536]
# <NDArray 1 @cpu(0)>, 'mean_label':
# [0.11909]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [70.925995]
# <NDArray 1 @cpu(0)>}
# [11/07/2020 19:50:35 INFO 139935395739456] nvidia-smi took: 0.0251679420471 secs to identify 0 gpus
# [11/07/2020 19:50:35 INFO 139935395739456] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Total Records Seen": {"count": 1, "max": 1155, "sum": 1155.0, "min": 1155}, "Max Records Seen Between Resets": {"count": 1, "max": 1055, "sum": 1055.0, "min": 1055}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1604778635.224058, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1604778635.224012}
#
# [2020-11-07 19:50:35.408] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 184, "num_examples": 11, "num_bytes": 50640}
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.33584013366699217, "sum": 0.33584013366699217, "min": 0.33584013366699217}}, "EndTime": 1604778635.408623, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604778635.408526}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.3361472873687744, "sum": 0.3361472873687744, "min": 0.3361472873687744}}, "EndTime": 1604778635.408732, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604778635.408709}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.33527861213684085, "sum": 0.33527861213684085, "min": 0.33527861213684085}}, "EndTime": 1604778635.408809, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604778635.408789}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.3360297775268555, "sum": 0.3360297775268555, "min": 0.3360297775268555}}, "EndTime": 1604778635.408879, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604778635.408862}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.5358295764923096, "sum": 0.5358295764923096, "min": 0.5358295764923096}}, "EndTime": 1604778635.408948, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604778635.408931}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0

#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.5331233196258545, "sum": 0.5331233196258545, "min": 0.5331233196258545}}, "EndTime": 1604778635.410606, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604778635.410588}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.5101010761260987, "sum": 0.5101010761260987, "min": 0.5101010761260987}}, "EndTime": 1604778635.410668, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604778635.41065}
#
# [11/07/2020 19:50:35 INFO 139935395739456] #quality_metric: host=algo-1, epoch=0, train absolute_loss_objective <loss>=0.335840133667
# [11/07/2020 19:50:35 INFO 139935395739456] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=absolute_loss_objective, value=0.334938024521
# [11/07/2020 19:50:35 INFO 139935395739456] Epoch 0: Loss improved. Updating best model
# [11/07/2020 19:50:35 INFO 139935395739456] Saving model for epoch: 0
# [11/07/2020 19:50:35 INFO 139935395739456] Saved checkpoint to "/tmp/tmppBhvOd/mx-mod-0000.params"
# [11/07/2020 19:50:35 INFO 139935395739456] #progress_metric: host=algo-1, completed 10 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Records Since Last Reset": {"count": 1, "max": 1055, "sum": 1055.0, "min": 1055}, "Total Batches Seen": {"count": 1, "max": 23, "sum": 23.0, "min": 23}, "Total Records Seen": {"count": 1, "max": 2210, "sum": 2210.0, "min": 2210}, "Max Records Seen Between Resets": {"count": 1, "max": 1055, "sum": 1055.0, "min": 1055}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1604778635.421442, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604778635.22431}
#
# [11/07/2020 19:50:35 INFO 139935395739456] #throughput_metric: host=algo-1, train throughput=5348.49374013 records/second
# [2020-11-07 19:50:35.626] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 6, "duration": 205, "num_examples": 11, "num_bytes": 50640}
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.2821706371307373, "sum": 0.2821706371307373, "min": 0.2821706371307373}}, "EndTime": 1604778635.62712, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604778635.627021}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.2857071990966797, "sum": 0.2857071990966797, "min": 0.2857071990966797}}, "EndTime": 1604778635.627231, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604778635.627207}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.28233302021026613, "sum": 0.28233302021026613, "min": 0.28233302021026613}}, "EndTime": 1604778635.6273, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604778635.627281}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.2856035041809082, "sum": 0.2856035041809082, "min": 0.2856035041809082}}, "EndTime": 1604778635.627353, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604778635.627335}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.38752805709838867, "sum": 0.38752805709838867, "min": 0.38752805709838867}}, "EndTime": 1604778635.627421, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604778635.627402}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.3835134792327881, "sum": 0.3835134792327881, "min": 0.3835134792327881}}, "EndTime": 1604778635.627488, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604778635.62747}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.4146872997283936, "sum": 0.4146872997283936, "min": 0.4146872997283936}}, "EndTime": 1604778635.62757, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604778635.627549}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.36866231727600096, "sum": 0.36866231727600096, "min": 0.36866231727600096}}, "EndTime": 1604778635.627666, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604778635.627647}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.2935107593536377, "sum": 0.2935107593536377, "min": 0.2935107593536377}}, "EndTime": 1604778635.627733, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604778635.627716}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.29012490367889404, "sum": 0.29012490367889404, "min": 0.29012490367889404}}, "EndTime": 1604778635.627793, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604778635.627778}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.2908901710510254, "sum": 0.2908901710510254, "min": 0.2908901710510254}}, "EndTime": 1604778635.627853, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604778635.627837}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.2912853240966797, "sum": 0.2912853240966797, "min": 0.2912853240966797}}, "EndTime": 1604778635.627909, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604778635.627893}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.3815564060211182, "sum": 0.3815564060211182, "min": 0.3815564060211182}}, "EndTime": 1604778635.627972, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604778635.627955}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0
"Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1604778635.92879}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.3506896934509277, "sum": 0.3506896934509277, "min": 0.3506896934509277}}, "EndTime": 1604778635.92887, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1604778635.928853}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.40026399326324463, "sum": 0.40026399326324463, "min": 0.40026399326324463}}, "EndTime": 1604778635.928934, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1604778635.928916}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.2761156387329102, "sum": 0.2761156387329102, "min": 0.2761156387329102}}, "EndTime": 1604778635.929002, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1604778635.928988}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.2754917030334473, "sum": 0.2754917030334473, "min": 0.2754917030334473}}, "EndTime": 1604778635.929067, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1604778635.929049}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.2808631725311279, "sum": 0.2808631725311279, "min": 0.2808631725311279}}, "EndTime": 1604778635.929128, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1604778635.929111}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.2810520687103272, "sum": 0.2810520687103272, "min": 0.2810520687103272}}, "EndTime": 1604778635.929193, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1604778635.929174}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.4049532871246338, "sum": 0.4049532871246338, "min": 0.4049532871246338}}, "EndTime": 1604778635.929256, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1604778635.929238}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.3042795391082764, "sum": 0.3042795391082764, "min": 0.3042795391082764}}, "EndTime": 1604778635.929319, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1604778635.929302}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.32944875526428224, "sum": 0.32944875526428224, "min": 0.32944875526428224}}, "EndTime": 1604778635.929381, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1604778635.929364}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.3247292289733887, "sum": 0.3247292289733887, "min": 0.3247292289733887}}, "EndTime": 1604778635.929438, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1604778635.929423}
#
# [11/07/2020 19:50:35 INFO 139935395739456] #quality_metric: host=algo-1, epoch=2, train absolute_loss_objective <loss>=0.2740442276
# [11/07/2020 19:50:35 INFO 139935395739456] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=absolute_loss_objective, value=0.27177912426
# [11/07/2020 19:50:35 INFO 139935395739456] Epoch 2: Loss improved. Updating best model
# [11/07/2020 19:50:35 INFO 139935395739456] Saving model for epoch: 2
# [11/07/2020 19:50:35 INFO 139935395739456] Saved checkpoint to "/tmp/tmp_ot6W5/mx-mod-0000.params"
# [11/07/2020 19:50:35 INFO 139935395739456] #progress_metric: host=algo-1, completed 30 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Records Since Last Reset": {"count": 1, "max": 1055, "sum": 1055.0, "min": 1055}, "Total Batches Seen": {"count": 1, "max": 45, "sum": 45.0, "min": 45}, "Total Records Seen": {"count": 1, "max": 4320, "sum": 4320.0, "min": 4320}, "Max Records Seen Between Resets": {"count": 1, "max": 1055, "sum": 1055.0, "min": 1055}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1604778635.943455, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1604778635.637698}
#
# [11/07/2020 19:50:35 INFO 139935395739456] #throughput_metric: host=algo-1, train throughput=3448.84914975 records/second
# [2020-11-07 19:50:36.214] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 10, "duration": 270, "num_examples": 11, "num_bytes": 50640}
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.27124795532226564, "sum": 0.27124795532226564, "min": 0.27124795532226564}}, "EndTime": 1604778636.214868, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1604778636.214764}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.2686856174468994, "sum": 0.2686856174468994, "min": 0.2686856174468994}}, "EndTime": 1604778636.214982, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1604778636.214958}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.27093995952606204, "sum": 0.27093995952606204, "min": 0.27093995952606204}}, "EndTime": 1604778636.215063, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1604778636.215043}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.2711999073028564, "sum": 0.2711999073028564, "min": 0.2711999073028564}}, "EndTime": 1604778636.215134, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1604778636.215116}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.31335299396514893, "sum": 0.31335299396514893, "min": 0.31335299396514893}}, "EndTime": 1604778636.215203, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 

#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.2663078260421753, "sum": 0.2663078260421753, "min": 0.2663078260421753}}, "EndTime": 1604778637.235892, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1604778637.235871}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.2649684915542603, "sum": 0.2649684915542603, "min": 0.2649684915542603}}, "EndTime": 1604778637.235989, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1604778637.23597}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.26492498207092285, "sum": 0.26492498207092285, "min": 0.26492498207092285}}, "EndTime": 1604778637.236054, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1604778637.236037}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.2653428945541382, "sum": 0.2653428945541382, "min": 0.2653428945541382}}, "EndTime": 1604778637.236115, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1604778637.236098}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.31688044738769533, "sum": 0.31688044738769533, "min": 0.31688044738769533}}, "EndTime": 1604778637.236176, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1604778637.23616}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.3185678596496582, "sum": 0.3185678596496582, "min": 0.3185678596496582}}, "EndTime": 1604778637.236235, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1604778637.236218}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.3124074296951294, "sum": 0.3124074296951294, "min": 0.3124074296951294}}, "EndTime": 1604778637.236299, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1604778637.236281}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.3364144973754883, "sum": 0.3364144973754883, "min": 0.3364144973754883}}, "EndTime": 1604778637.236364, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1604778637.236347}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.26593235015869143, "sum": 0.26593235015869143, "min": 0.26593235015869143}}, "EndTime": 1604778637.236428, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1604778637.23641}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.2656653642654419, "sum": 0.2656653642654419, "min": 0.2656653642654419}}, "EndTime": 1604778637.23649, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1604778637.236474}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.2665269947052002, "sum": 0.2665269947052002, "min": 0.2665269947052002}}, "EndTime": 1604778637.236549, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1604778637.236533}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.2654567356109619, "sum": 0.2654567356109619, "min": 0.2654567356109619}}, "EndTime": 1604778637.236611, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1604778637.236595}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.3459239225387573, "sum": 0.3459239225387573, "min": 0.3459239225387573}}, "EndTime": 1604778637.236668, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1604778637.236654}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.2992647542953491, "sum": 0.2992647542953491, "min": 0.2992647542953491}}, "EndTime": 1604778637.236729, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1604778637.236711}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.28239807415008544, "sum": 0.28239807415008544, "min": 0.28239807415008544}}, "EndTime": 1604778637.236793, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1604778637.236774}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.30787948036193846, "sum": 0.30787948036193846, "min": 0.30787948036193846}}, "EndTime": 1604778637.236856, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1604778637.236839}
#
# [11/07/2020 19:50:37 INFO 139935395739456] #quality_metric: host=algo-1, epoch=7, train absolute_loss_objective <loss>=0.265950737953
# [11/07/2020 19:50:37 INFO 139935395739456] #early_stopping_criteria_metric: host=algo-1, epoch=7, criteria=absolute_loss_objective, value=0.264828636169
# [11/07/2020 19:50:37 INFO 139935395739456] Saving model for epoch: 7
# [11/07/2020 19:50:37 INFO 139935395739456] Saved checkpoint to "/tmp/tmp9HUwQO/mx-mod-0000.params"
# [11/07/2020 19:50:37 INFO 139935395739456] Early stop condition met. Stopping training.
# [11/07/2020 19:50:37 INFO 139935395739456] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Records Since Last Reset": {"count": 1, "max": 1055, "sum": 1055.0, "min": 1055}, "Total Batches Seen": {"count": 1, "max": 100, "sum": 100.0, "min": 100}, "Total Records Seen": {"count": 1, "max": 9595, "sum": 9595.0, "min": 9595}, "Max Records Seen Between Resets": {"count": 1, "max": 1055, "sum": 1055.0, "min": 1055}, "Reset Count": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1604778637.247723, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1604778637.019422}
#
# [11/07/2020 19:50:37 INFO 139935395739456] #throughput_metric: host=algo-1, train throughput=4618.32295557 records/second
# [11/07/2020 19:50:37 WARNING 139935395739456] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [11/07/2020 19:50:37 WARNING 139935395739456] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2020-11-07 19:50:37.249] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 20, "duration": 1, "num_examples": 1, "num_bytes": 4800}
# [2020-11-07 19:50:37.282] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 22, "duration": 27, "num_examples": 11, "num_bytes": 50640}
# [11/07/2020 19:50:37 INFO 139935395739456] #train_score (algo-1) : ('absolute_loss_objective', 0.11731730456600822)
# [11/07/2020 19:50:37 INFO 139935395739456] #train_score (algo-1) : ('mse', 0.21217091162622823)
# [11/07/2020 19:50:37 INFO 139935395739456] #train_score (algo-1) : ('absolute_loss', 0.11731730456600822)
# [11/07/2020 19:50:37 INFO 139935395739456] #quality_metric: host=algo-1, train absolute_loss_objective <loss>=0.117317304566
# [11/07/2020 19:50:37 INFO 139935395739456] #quality_metric: host=algo-1, train mse <loss>=0.212170911626
# [11/07/2020 19:50:37 INFO 139935395739456] #quality_metric: host=algo-1, train absolute_loss <loss>=0.117317304566
# [11/07/2020 19:50:37 INFO 139935395739456] Best model found for hyperparameters: {"lr_scheduler_step": 100, "wd": 1, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.005, "lr_scheduler_minimum_lr": 0.0001}
# [11/07/2020 19:50:37 INFO 139935395739456] Saved checkpoint to "/tmp/tmpbeTpxp/mx-mod-0000.params"
# [2020-11-07 19:50:37.287] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 0, "duration": 2274, "num_examples": 1, "num_bytes": 4800}
# [2020-11-07 19:50:37.295] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 1, "duration": 7, "num_examples": 3, "num_bytes": 12672}
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Number of Batches Since Last Reset": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Number of Records Since Last Reset": {"count": 1, "max": 264, "sum": 264.0, "min": 264}, "Total Batches Seen": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Total Records Seen": {"count": 1, "max": 264, "sum": 264.0, "min": 264}, "Max Records Seen Between Resets": {"count": 1, "max": 264, "sum": 264.0, "min": 264}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1604778637.295188, "Dimensions": {"Host": "algo-1", "Meta": "test_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1604778637.287494}
#
# [11/07/2020 19:50:37 INFO 139935395739456] #test_score (algo-1) : ('absolute_loss_objective', 0.10764949971979315)
# [11/07/2020 19:50:37 INFO 139935395739456] #test_score (algo-1) : ('mse', 0.13104718562328455)
# [11/07/2020 19:50:37 INFO 139935395739456] #test_score (algo-1) : ('absolute_loss', 0.10764949971979315)
# [11/07/2020 19:50:37 INFO 139935395739456] #quality_metric: host=algo-1, test absolute_loss_objective <loss>=0.10764949972
# [11/07/2020 19:50:37 INFO 139935395739456] #quality_metric: host=algo-1, test mse <loss>=0.131047185623
# [11/07/2020 19:50:37 INFO 139935395739456] #quality_metric: host=algo-1, test absolute_loss <loss>=0.10764949972
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 2542.696952819824, "sum": 2542.696952819824, "min": 2542.696952819824}, "finalize.time": {"count": 1, "max": 35.943031311035156, "sum": 35.943031311035156, "min": 35.943031311035156}, "initialize.time": {"count": 1, "max": 210.31999588012695, "sum": 210.31999588012695, "min": 210.31999588012695}, "check_early_stopping.time": {"count": 8, "max": 1.4331340789794922, "sum": 6.001472473144531, "min": 0.21910667419433594}, "setuptime": {"count": 1, "max": 30.797958374023438, "sum": 30.797958374023438, "min": 30.797958374023438}, "update.time": {"count": 8, "max": 299.76701736450195, "sum": 1973.4582901000977, "min": 191.97607040405273}, "epochs": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1604778637.3008, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1604778635.010903}
#
#
# 2020-11-07 19:50:48 Completed - Training job completed
# Training seconds: 86
# Billable seconds: 86

# %% [markdown]
# ## Deploying the Model to Make Predictions

# %%
# An instance of the linear-learner predictor is created
linear_predictor = linear.deploy(initial_instance_count=1, instance_type="ml.t2.medium")
# Out:
# -----------------!

# %%
# Linear predictor configurations
# linear_predictor.content_type = "text/csv"
linear_predictor.serializer = csv_serializer
linear_predictor.deserializer = json_deserializer

# %%
# Making some predictions using the test data.
result = linear_predictor.predict(X_test)
y_predictions = np.array([r["score"] for r in result["predictions"]])
y_predictions[:5]
# Out:
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# array([0.00085302, 0.00252608, 0.00260575, 0.00276509, 0.00157005])

# %% [markdown]
# ## Model Evaluation

# %%
# Plotting predicted Vs. actual values
plt.plot(np.array(y_test), label="actual")
plt.plot(y_predictions, label="predict")
plt.legend()
plt.show()

# %%
# Calculating the RMSE and R2 scores
rmse = np.sqrt(mean_squared_error(y_test, y_predictions))
r2 = r2_score(y_test, y_predictions)

print("RMSE: {}".format(rmse))
print("R2 score: {}".format(r2))
# Out:
# RMSE: 0.36200439646214744
# R2 score: -0.09238525522643481

# %% [markdown]
# ## Delete Amazon SageMaker end-point

# %%
sagemaker.Session().delete_endpoint(linear_predictor.endpoint)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-22-f4940a87fb1d> in <module>
# ----> 1 sagemaker.Session().delete_endpoint(linear_predictor.endpoint)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/session.py in delete_endpoint(self, endpoint_name)
#    2754         """
#    2755         LOGGER.info("Deleting endpoint with name: %s", endpoint_name)
# -> 2756         self.sagemaker_client.delete_endpoint(EndpointName=endpoint_name)
#    2757
#    2758     def delete_endpoint_config(self, endpoint_config_name):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     674             error_code = parsed_response.get("Error", {}).get("Code")
#     675             error_class = self.exceptions.from_code(error_code)
# --> 676             raise error_class(parsed_response, operation_name)
#     677         else:
#     678             return parsed_response
#
# ClientError: An error occurred (ValidationException) when calling the DeleteEndpoint operation: Could not find endpoint "arn:aws:sagemaker:us-west-2:061915500351:endpoint/linear-learner-2020-11-07-19-51-36-791".
